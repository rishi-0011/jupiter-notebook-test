# %%
import pandas as pd
sd=pd.read_csv("C:\\Users\\Hp\\Downloads\\50_Startups.csv")
sd
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
sd.shape
# Out:
# (50, 5)

# %%
sd.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
sd.dtypes
# Out:
# R&D Spend          float64
# Administration     float64
# Marketing Spend    float64
# State               object
# Profit             float64
# dtype: object

# %%
sd['State'].value_counts()
# Out:
# State
# New York      17
# California    17
# Florida       16
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.pairplot(sd)
plt.show()

# %%
sd=pd.get_dummies(sd,columns=['State'])
sd.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit  State_California  \
# 0  165349.20       136897.80        471784.10  192261.83             False
# 1  162597.70       151377.59        443898.53  191792.06              True
# 2  153441.51       101145.55        407934.54  191050.39             False
# 3  144372.41       118671.85        383199.62  182901.99             False
# 4  142107.34        91391.77        366168.42  166187.94             False
#
#    State_Florida  State_New York
# 0          False            True
# 1          False           False
# 2           True           False
# 3          False            True
# 4           True           False

# %%
y=sd['Profit']
x=sd.drop(['Profit'],axis=1)
y.head()
# Out:
# 0    192261.83
# 1    191792.06
# 2    191050.39
# 3    182901.99
# 4    166187.94
# Name: Profit, dtype: float64

# %%
x.head()
# Out:
#    R&D Spend  Administration  Marketing Spend  State_California  \
# 0  165349.20       136897.80        471784.10             False
# 1  162597.70       151377.59        443898.53              True
# 2  153441.51       101145.55        407934.54             False
# 3  144372.41       118671.85        383199.62             False
# 4  142107.34        91391.77        366168.42             False
#
#    State_Florida  State_New York
# 0          False            True
# 1          False           False
# 2           True           False
# 3          False            True
# 4           True           False

# %%
#4.scaling
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x_scaled=scaler.fit_transform(x)
x_scaled
# Out:
# array([[1.        , 0.65174393, 1.        , 0.        , 0.        ,
#         1.        ],
#        [0.98335946, 0.76197173, 0.94089337, 1.        , 0.        ,
#         0.        ],
#        [0.92798459, 0.37957895, 0.8646636 , 0.        , 1.        ,
#         0.        ],
#        [0.87313643, 0.51299839, 0.81223513, 0.        , 0.        ,
#         1.        ],
#        [0.85943772, 0.30532804, 0.77613557, 0.        , 1.        ,
#         0.        ],
#        [0.797566  , 0.3694479 , 0.76912588, 0.        , 0.        ,
#         1.        ],
#        [0.81412828, 0.73016111, 0.27071031, 1.        , 0.        ,
#         0.        ],
#        [0.7880179 , 0.71745725, 0.68649342, 0.        , 1.        ,
#         0.        ],
#        [0.72901786, 0.74173276, 0.66049977, 0.        , 0.        ,
#         1.        ],
#        [0.74590551, 0.43692884, 0.64644319, 1.        , 0.        ,
#         0.        ],
#        [0.61635061, 0.45150637, 0.48573267, 0.        , 1.        ,
# ...

# %%
#for splitting the dataset into training and testing
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (40, 6)

# %%
y_train.shape
# Out:
# (40,)

# %%
x_test.shape,y_test.shape
# Out:
# ((10, 6), (10,))

# %%
#5.apply the best ml algorithm to training dataset

# %%
#6.evaluate the model
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import numpy as np
y_pred=model.predict(x_test)
y_pred[:5]
# Out:
# array([126362.87908255,  84608.45383633,  99677.49425146,  46357.46068582,
#        128750.48288505])

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)*100
# Out:
# 89.87266414329449

# %%
er=pd.read_csv("C:\\Users\\Hp\\Downloads\\weight-height.csv")
er
# Out:
#       Gender     Weight      Height
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
er.isnull().sum()
# Out:
# Gender    0
# Weight    0
# Height    0
# dtype: int64

# %%
er.dtypes
# Out:
# Gender     object
# Weight    float64
# Height    float64
# dtype: object

# %%
er.shape
# Out:
# (10000, 3)

# %%
er.info
# Out:
# <bound method DataFrame.info of       Gender     Weight      Height
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]>

# %%
er['Gender'].replace({'Male':1,'Female':0},inplace=True)
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13688\571867063.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   er['Gender'].replace({'Male':1,'Female':0},inplace=True)
# C:\Users\Hp\AppData\Local\Temp\ipykernel_13688\571867063.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
er
# Out:
#       Gender     Weight      Height
# 0          1  73.847017  241.893563
# 1          1  68.781904  162.310473
# 2          1  74.110105  212.740856
# 3          1  71.730978  220.042470
# 4          1  69.881796  206.349801
# ...      ...        ...         ...
# 9995       0  66.172652  136.777454
# 9996       0  67.067155  170.867906
# 9997       0  63.867992  128.475319
# 9998       0  69.034243  163.852461
# 9999       0  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot(er)
plt.show()

# %%
er['Gender'].value_counts()
# Out:
# Gender
# 1    5000
# 0    5000
# Name: count, dtype: int64

# %%
y=er['Height']
x=er.drop(['Height'],axis=1)
y.head()
# Out:
# 0    241.893563
# 1    162.310473
# 2    212.740856
# 3    220.042470
# 4    206.349801
# Name: Height, dtype: float64

# %%
x.head()
# Out:
#    Gender     Weight
# 0       1  73.847017
# 1       1  68.781904
# 2       1  74.110105
# 3       1  71.730978
# 4       1  69.881796

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train.shape
# Out:
# (8000, 2)

# %%
y_train.shape
# Out:
# (8000,)

# %%
x_test.shape,y_test.shape
# Out:
# ((2000, 2), (2000,))

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
import numpy as np
y_pred=model.predict(x_test)
y_pred[:5]
# Out:
# array([141.93828842, 176.55658781, 219.77836196, 148.83188403,
#        162.09207591])

# %%
y_test[:5]
# Out:
# 9394    138.085796
# 898     187.363366
# 2398    216.533191
# 5906    131.761443
# 2343    157.718438
# Name: Height, dtype: float64

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)*100
# Out:
# 90.5288982474689

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,root_mean_squared_error
mean_squared_error(y_test,y_pred)
# Out:
# 97.87152217990106

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 7.955916524719641

# %%
root_mean_squared_error(y_test,y_pred)
# Out:
# 9.893003698569059
